# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df= pd.read_csv('train_walmart.csv')

# %%
features_df=pd.read_csv('features.csv')
stores_df=pd.read_csv('stores.csv')

# %%
train_df
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  2010-02-05      24924.50      False
# 1           1     1  2010-02-12      46039.49       True
# 2           1     1  2010-02-19      41595.55      False
# 3           1     1  2010-02-26      19403.54      False
# 4           1     1  2010-03-05      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  2012-09-28        508.37      False
# 421566     45    98  2012-10-05        628.10      False
# 421567     45    98  2012-10-12       1061.02      False
# 421568     45    98  2012-10-19        760.01      False
# 421569     45    98  2012-10-26       1076.80      False
#
# [421570 rows x 5 columns]

# %%
features_df
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2010-02-05        42.31       2.572        NaN        NaN
# 1         1  2010-02-12        38.51       2.548        NaN        NaN
# 2         1  2010-02-19        39.93       2.514        NaN        NaN
# 3         1  2010-02-26        46.63       2.561        NaN        NaN
# 4         1  2010-03-05        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0           NaN        NaN        NaN  211.096358         8.106      False
# 1           NaN        NaN        NaN  211.242170         8.106       True
# 2           NaN        NaN        NaN  211.289143         8.106      False
# 3           NaN        NaN        NaN  211.319643         8.106      False
# 4           NaN        NaN        NaN  211.350143         8.106      False
# ...         ...        ...        ...         ...           ...        ...
# 8185       3.00    2449.97    3169.69         NaN           NaN      False
# 8186     582.74    5797.47    1514.93         NaN           NaN      False
# 8187      85.72     744.84    2150.36         NaN           NaN      False
# 8188     204.19     363.00    1059.46         NaN           NaN      False
# 8189       2.06      10.88    1864.57         NaN           NaN      False
#
# [8190 rows x 12 columns]

# %%
stores_df
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 5       6    A  202505
# 6       7    B   70713
# 7       8    A  155078
# 8       9    B  125833
# 9      10    B  126512
# 10     11    A  207499
# 11     12    B  112238
# 12     13    A  219622
# 13     14    A  200898
# 14     15    B  123737
# 15     16    B   57197
# 16     17    B   93188
# 17     18    B  120653
# 18     19    A  203819
# 19     20    A  203742
# 20     21    B  140167
# 21     22    B  119557
# 22     23    B  114533
# 23     24    A  203819
# 24     25    B  128107
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 28     29    B   93638
# 29     30    C   42988
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 34     35    B  103681
# 35     36    A   39910
# 36     37    C   39910
# 37     38    C   39690
# 38     39    A  184109
# 39     40    A  155083
# 40     41    A  196321
# 41     42    C   39690
# 42     43    C   41062
# 43     44    C   39910
# 44     45    B  118221

# %%
train_df.isnull().sum()
# Out:
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday       0
# dtype: int64

# %%
features_df.isnull().sum()
# Out:
# Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# dtype: int64

# %%
stores_df.isnull().sum()
# Out:
# Store    0
# Type     0
# Size     0
# dtype: int64

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB

# %%
## inner join
dataset_m = features_df.merge(stores_df,how='inner',on='Store')

# %%
features_df.shape
# Out:
# (8190, 12)

# %%
dataset_m.shape
# Out:
# (8190, 14)

# %%
dataset_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8190 entries, 0 to 8189
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
#  12  Type          8190 non-null   object
#  13  Size          8190 non-null   int64
# dtypes: bool(1), float64(9), int64(2), object(2)
# memory usage: 903.8+ KB

# %%
from datetime import datetime
dataset_m['Date'] = pd.to_datetime(dataset_m['Date'])
train_df["Date"] = pd.to_datetime(train_df['Date'])

# %%
df = train_df.merge(dataset_m, how='inner',on = ['Store','Date','IsHoliday'])

# %%
df
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1 2010-02-05      24924.50      False        42.31
# 1           1     2 2010-02-05      50605.27      False        42.31
# 2           1     3 2010-02-05      13740.12      False        42.31
# 3           1     4 2010-02-05      39954.04      False        42.31
# 4           1     5 2010-02-05      32229.38      False        42.31
# ...       ...   ...        ...           ...        ...          ...
# 421565     45    93 2012-10-26       2487.80      False        58.85
# 421566     45    94 2012-10-26       5203.31      False        58.85
# 421567     45    95 2012-10-26      56017.47      False        58.85
# 421568     45    97 2012-10-26       6817.48      False        58.85
# 421569     45    98 2012-10-26       1076.80      False        58.85
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# 0            2.572        NaN        NaN        NaN        NaN        NaN
# 1            2.572        NaN        NaN        NaN        NaN        NaN
# 2            2.572        NaN        NaN        NaN        NaN        NaN
# 3            2.572        NaN        NaN        NaN        NaN        NaN
# 4            2.572        NaN        NaN        NaN        NaN        NaN
# ...            ...        ...        ...        ...        ...        ...
# 421565       3.882    4018.91      58.08      100.0     211.94     858.33
# 421566       3.882    4018.91      58.08      100.0     211.94     858.33
# 421567       3.882    4018.91      58.08      100.0     211.94     858.33
# 421568       3.882    4018.91      58.08      100.0     211.94     858.33
# 421569       3.882    4018.91      58.08      100.0     211.94     858.33
#
#                CPI  Unemployment Type    Size
# 0       211.096358         8.106    A  151315
# 1       211.096358         8.106    A  151315
# 2       211.096358         8.106    A  151315
# 3       211.096358         8.106    A  151315
# 4       211.096358         8.106    A  151315
# ...            ...           ...  ...     ...
# 421565  192.308899         8.667    B  118221
# 421566  192.308899         8.667    B  118221
# 421567  192.308899         8.667    B  118221
# 421568  192.308899         8.667    B  118221
# 421569  192.308899         8.667    B  118221
#
# [421570 rows x 16 columns]

# %%
df['week'] = df.Date.dt.isocalendar().week

# %%
df['year'] = df.Date.dt.isocalendar().year

# %%
df
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1 2010-02-05      24924.50      False        42.31
# 1           1     2 2010-02-05      50605.27      False        42.31
# 2           1     3 2010-02-05      13740.12      False        42.31
# 3           1     4 2010-02-05      39954.04      False        42.31
# 4           1     5 2010-02-05      32229.38      False        42.31
# ...       ...   ...        ...           ...        ...          ...
# 421565     45    93 2012-10-26       2487.80      False        58.85
# 421566     45    94 2012-10-26       5203.31      False        58.85
# 421567     45    95 2012-10-26      56017.47      False        58.85
# 421568     45    97 2012-10-26       6817.48      False        58.85
# 421569     45    98 2012-10-26       1076.80      False        58.85
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# 0            2.572        NaN        NaN        NaN        NaN        NaN
# 1            2.572        NaN        NaN        NaN        NaN        NaN
# 2            2.572        NaN        NaN        NaN        NaN        NaN
# 3            2.572        NaN        NaN        NaN        NaN        NaN
# 4            2.572        NaN        NaN        NaN        NaN        NaN
# ...            ...        ...        ...        ...        ...        ...
# 421565       3.882    4018.91      58.08      100.0     211.94     858.33
# 421566       3.882    4018.91      58.08      100.0     211.94     858.33
# 421567       3.882    4018.91      58.08      100.0     211.94     858.33
# 421568       3.882    4018.91      58.08      100.0     211.94     858.33
# 421569       3.882    4018.91      58.08      100.0     211.94     858.33
#
#                CPI  Unemployment Type    Size  week  year
# 0       211.096358         8.106    A  151315     5  2010
# 1       211.096358         8.106    A  151315     5  2010
# 2       211.096358         8.106    A  151315     5  2010
# 3       211.096358         8.106    A  151315     5  2010
# 4       211.096358         8.106    A  151315     5  2010
# ...            ...           ...  ...     ...   ...   ...
# 421565  192.308899         8.667    B  118221    43  2012
# 421566  192.308899         8.667    B  118221    43  2012
# 421567  192.308899         8.667    B  118221    43  2012
# 421568  192.308899         8.667    B  118221    43  2012
# 421569  192.308899         8.667    B  118221    43  2012
#
# [421570 rows x 18 columns]

# %%
def scatter(dff,column):
  plt.figure(figsize=(12,8))
  plt.scatter(dff[column],dff['Weekly_Sales'])
  plt.ylabel('weekly sales')
  plt.xlabel('column')

# %%
scatter(df,'Store')

# %%
scatter(df,'Dept')

# %%
df.year.value_counts()
# Out:
# 2011    153453
# 2010    140679
# 2012    127438
# Name: year, dtype: Int64

# %%
#in year 2011 average weekly sales using line plot
#so filter data of yr 2011 grouby week and do average of sales- two columns

# %%
weekly_sales_2011=df[df['year']==2011].groupby(['week'])['Weekly_Sales'].mean()

# %%
weekly_sales_2011
# Out:
# week
# 1     14599.244973
# 2     13891.283484
# 3     13932.367385
# 4     13566.239462
# 5     15773.448776
# 6     16111.706191
# 7     16541.991212
# 8     15049.747558
# 9     15882.557045
# 10    15056.450540
# 11    15216.115961
# 12    14573.827050
# 13    14726.869261
# 14    15634.571312
# 15    15229.708141
# 16    16472.653827
# 17    14745.946064
# 18    15757.215296
# 19    15317.204186
# 20    15002.247279
# 21    15390.233449
# 22    16691.305332
# 23    16302.918830
# 24    16111.226407
# 25    15649.418342
# 26    16232.862334
# 27    16328.646803
# 28    15566.323502
# 29    15526.204180
# 30    14965.150490
# 31    16393.126313
# 32    15774.068626
# 33    15888.028317
# 34    16068.095036
# 35    15387.122167
# 36    15809.069483
# 37    14865.566897
# 38    14446.431089
# 39    14298.824402
# 40    15960.678959
# 41    15062.736015
# 42    15521.325691
# 43    15470.924781
# 44    16471.071192
# 45    16348.811046
# 46    15683.546288
# 47    22043.563476
# 48    16496.511854
# 49    18458.853056
# 50    19942.149333
# 51    25437.146122
# 52    15332.154858
# Name: Weekly_Sales, dtype: float64

# %%
sns.lineplot(weekly_sales_2011.index,weekly_sales_2011.values, color='red')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
weekly_sales_2010=df[df['year']==2010].groupby(['week'])['Weekly_Sales'].mean()

# %%
sns.lineplot(weekly_sales_2010.index,weekly_sales_2010.values, color='maroon')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
weekly_sales_2012=df[df['year']==2012].groupby(['week'])['Weekly_Sales'].mean()

# %%
sns.lineplot(weekly_sales_2012.index,weekly_sales_2012.values, color='green')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#combine plot
plt.figure(figsize=(20,10))
sns.lineplot(weekly_sales_2010.index,weekly_sales_2010.values)
sns.lineplot(weekly_sales_2011.index,weekly_sales_2011.values)
sns.lineplot(weekly_sales_2012.index,weekly_sales_2012.values)
plt.grid()
plt.title('Average weekly sales per year',fontsize=30)
plt.ylabel('sales',fontsize=20)
plt.xlabel('weeks',fontsize=20)
plt.xticks(np.arange(1,60,step=1))
plt.legend(['2010','2011','2012'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#data distribution of weekly sales
sns.distplot(df['Weekly_Sales'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#box plot
sns.boxplot(x='Type',y='Size',data=df)

# %%
#which 5 stores have highest average sales overall
weekly_sales_store=df.groupby(['Store'])['Weekly_Sales'].mean()

# %%
weekly_sales_store
# Out:
# Store
# 1     21710.543621
# 2     26898.070031
# 3      6373.033983
# 4     29161.210415
# 5      5053.415813
# 6     21913.243624
# 7      8358.766148
# 8     13133.014768
# 9      8772.890379
# 10    26332.303819
# 11    19276.762751
# 12    14867.308619
# 13    27355.136891
# 14    28784.851727
# 15     9002.493073
# 16     7863.224124
# 17    12954.393636
# 18    15733.313136
# 19    20362.126734
# 20    29508.301592
# 21    11283.435496
# 22    15181.218886
# 23    19776.180881
# 24    18969.106500
# 25    10308.157810
# 26    14554.129672
# 27    24826.984536
# 28    18714.889803
# 29     8158.810609
# 30     8764.237719
# 31    19681.907464
# 32    16351.621855
# 33     5728.414053
# 34    13522.081671
# 35    13803.596986
# 36     8584.412563
# 37    10297.355026
# 38     7492.478460
# 39    21000.763562
# 40    13763.632803
# 41    17976.004648
# 42    11443.370118
# 43    13415.114118
# 44     6038.929814
# 45    11662.897315
# Name: Weekly_Sales, dtype: float64

# %%
pd.DataFrame(weekly_sales_store).sort_values(by='Weekly_Sales',ascending=False).style.bar()
# Out:
# <style type="text/css">
# #T_90c7c_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
# }
# #T_90c7c_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 98.6%, transparent 98.6%);
# }
# #T_90c7c_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 97.0%, transparent 97.0%);
# }
# #T_90c7c_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 91.2%, transparent 91.2%);
# }
# #T_90c7c_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 89.3%, transparent 89.3%);
# }
# #T_90c7c_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 87.0%, transparent 87.0%);
# }
# #T_90c7c_row6_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 80.9%, transparent 80.9%);
# }
# #T_90c7c_row7_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 68.9%, transparent 68.9%);
# }
# #T_90c7c_row8_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 68.1%, transparent 68.1%);
# }
# #T_90c7c_row9_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 65.2%, transparent 65.2%);
# }
# #T_90c7c_row10_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 62.6%, transparent 62.6%);
# }
# #T_90c7c_row11_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 60.2%, transparent 60.2%);
# }
# #T_90c7c_row12_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 59.8%, transparent 59.8%);
# }
# #T_90c7c_row13_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 58.2%, transparent 58.2%);
# }
# #T_90c7c_row14_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 56.9%, transparent 56.9%);
# }
# #T_90c7c_row15_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 55.9%, transparent 55.9%);
# }
# #T_90c7c_row16_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 52.8%, transparent 52.8%);
# }
# #T_90c7c_row17_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 46.2%, transparent 46.2%);
# }
# #T_90c7c_row18_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 43.7%, transparent 43.7%);
# }
# #T_90c7c_row19_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 41.4%, transparent 41.4%);
# }
# #T_90c7c_row20_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 40.1%, transparent 40.1%);
# }
# #T_90c7c_row21_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 38.8%, transparent 38.8%);
# }
# #T_90c7c_row22_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 35.8%, transparent 35.8%);
# }
# #T_90c7c_row23_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 35.6%, transparent 35.6%);
# }
# #T_90c7c_row24_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 34.6%, transparent 34.6%);
# }
# #T_90c7c_row25_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 34.2%, transparent 34.2%);
# }
# #T_90c7c_row26_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 33.0%, transparent 33.0%);
# }
# #T_90c7c_row27_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 32.3%, transparent 32.3%);
# }
# #T_90c7c_row28_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 27.0%, transparent 27.0%);
# }
# #T_90c7c_row29_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 26.1%, transparent 26.1%);
# }
# #T_90c7c_row30_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 25.5%, transparent 25.5%);
# }
# #T_90c7c_row31_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 21.5%, transparent 21.5%);
# }
# #T_90c7c_row32_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 21.4%, transparent 21.4%);
# }
# #T_90c7c_row33_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 16.1%, transparent 16.1%);
# }
# #T_90c7c_row34_col0, #T_90c7c_row35_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 15.2%, transparent 15.2%);
# }
# #T_90c7c_row36_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 14.4%, transparent 14.4%);
# }
# #T_90c7c_row37_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 13.5%, transparent 13.5%);
# }
# #T_90c7c_row38_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 12.7%, transparent 12.7%);
# }
# #T_90c7c_row39_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 11.5%, transparent 11.5%);
# }
# #T_90c7c_row40_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 10.0%, transparent 10.0%);
# }
# #T_90c7c_row41_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.4%, transparent 5.4%);
# }
# #T_90c7c_row42_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 4.0%, transparent 4.0%);
# }
# #T_90c7c_row43_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.8%, transparent 2.8%);
# }
# #T_90c7c_row44_col0 {
#   width: 10em;
#   height: 80%;
# }
# </style>
# <table id="T_90c7c_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Weekly_Sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Store</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90c7c_level0_row0" class="row_heading level0 row0" >20</th>
#       <td id="T_90c7c_row0_col0" class="data row0 col0" >29508.301592</td>
#     </tr>
#     <tr>
#       <th id="T_90c7c_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_90c7c_row1_col0" class="data row1 col0" >29161.210415</td>
#     </tr>
#     <tr>
#       <th id="T_90c7c_level0_row2" class="row_heading level0 row2" >14</th>
#       <td id="T_90c7c_row2_col0" class="data row2 col0" >28784.851727</td>
#     </tr>
#     <tr>
#       <th id="T_90c7c_level0_row3" class="row_heading level0 row3" >13</th>
#       <td id="T_90c7c_row3_col0" class="data row3 col0" >27355.136891</td>
#     </tr>
#     <tr>
#       <th id="T_90c7c_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_90c7c_row4_col0" class="data row4 col0" >26898.070031</td>
#     </tr>
#     <tr>
#       <th id="T_90c7c_level0_row5" class="row_heading level0 row5" >10</th>
#       <td id="T_90c7c_row5_col0" class="data row5 col0" >26332.303819</td>
#     </tr>
#     <tr>
#       <th id="T_90c7c_level0_row6" class="row_heading level0 row6" >27</th>
#       <td id="T_90c7c_row6_col0" class="data row6 col0" >24826.984536</td>
#     </tr>
#     <tr>
#       <th id="T_90c7c_level0_row7" class="row_heading level0 row7" >6</th>
#       <td id="T_90c7c_row7_col0" class="data row7 col0" >21913.243624</td>
#     </tr>
#     <tr>
#       <th id="T_90c7c_level0_row8" class="row_heading level0 row8" >1</th>
#       <td id="T_90c7c_row8_col0" class="data row8 col0" >21710.543621</td>
#     </tr>
#     <tr>
#       <th id="T_90c7c_level0_row9" class="row_heading level0 row9" >39</th>
#       <td id="T_90c7c_row9_col0" class="data row9 col0" >21000.763562</td>
#     </tr>
#     <tr>
#       <th id="T_90c7c_level0_row10" class="row_heading level0 row10" >19</th>
#       <td id="T_90c7c_row10_col0" class="data row10 col0" >20362.126734</td>
#     </tr>
#     <tr>
#       <th id="T_90c7c_level0_row11" class="row_heading level0 row11" >23</th>
#       <td id="T_90c7c_row11_col0" class="data row11 col0" >19776.180881</td>
#     </tr>
#     <tr>
#       <th id="T_90c7c_level0_row12" class="row_heading level0 row12" >31</th>
#       <td id="T_90c7c_row12_col0" class="data row12 col0" >19681.907464</td>
#     </tr>
#     <tr>

# %%
len(df.Store.unique())
# Out:
# 45

# %%
#bar graph having stores on x axis and avg weekly sales on y axis 
#combine plot
plt.figure(figsize=(20,10))
sns.barplot(weekly_sales_store.index,weekly_sales_store.values, palette='dark')

plt.grid()
plt.title('Average weekly sales per store',fontsize=30)
plt.ylabel('sales',fontsize=20)
plt.xlabel('stores',fontsize=20)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'stores')

# %%
weekly_sales_dept=df.groupby(['Dept'])['Weekly_Sales'].mean()
plt.figure(figsize=(20,10))
sns.barplot(weekly_sales_dept.index,weekly_sales_dept.values, palette='dark')

plt.grid()
plt.title('Average weekly sales per dept',fontsize=30)
plt.ylabel('sales',fontsize=20)
plt.xlabel('dept',fontsize=20)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'dept')

# %%
weekly_sales_dept.sort_values(ascending=False)
# Out:
# Dept
# 92    75204.870531
# 95    69824.423080
# 38    61090.619568
# 72    50566.515417
# 65    45441.706224
#           ...
# 51       21.931729
# 39       11.123750
# 78        7.296638
# 43        1.193333
# 47       -7.682554
# Name: Weekly_Sales, Length: 81, dtype: float64

# %%
#heatmap of correlation matrix
#for more readability

plt.figure(figsize=(20,8))
sns.heatmap(df.corr(),cmap='viridis',linewidth=2.0,linecolor='black',annot=True)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5]),
#  <a list of 16 Text major ticklabel objects>)

# %%
corr=df.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr,annot=True,cmap='magma')

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),cmap='rocket',linecolor='black',annot=True)

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),cmap='magma',linewidths=2.0,linecolor='black',annot=True)

# %%
plt.figure(figsize=(18,8))
sns.heatmap(df.corr(),vmin=0.5,cmap='Greens',linewidth=2,center=None,linecolor='black',annot=True)

# %%
plt.figure(figsize=(20,8))
sns.heatmap(df.corr(),cmap='coolwarm',linewidth=0.5,linecolor='black',annot=True)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5]),
#  <a list of 16 Text major ticklabel objects>)

# %%
df
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1 2010-02-05      24924.50      False        42.31
# 1           1     2 2010-02-05      50605.27      False        42.31
# 2           1     3 2010-02-05      13740.12      False        42.31
# 3           1     4 2010-02-05      39954.04      False        42.31
# 4           1     5 2010-02-05      32229.38      False        42.31
# ...       ...   ...        ...           ...        ...          ...
# 421565     45    93 2012-10-26       2487.80      False        58.85
# 421566     45    94 2012-10-26       5203.31      False        58.85
# 421567     45    95 2012-10-26      56017.47      False        58.85
# 421568     45    97 2012-10-26       6817.48      False        58.85
# 421569     45    98 2012-10-26       1076.80      False        58.85
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# 0            2.572        NaN        NaN        NaN        NaN        NaN
# 1            2.572        NaN        NaN        NaN        NaN        NaN
# 2            2.572        NaN        NaN        NaN        NaN        NaN
# 3            2.572        NaN        NaN        NaN        NaN        NaN
# 4            2.572        NaN        NaN        NaN        NaN        NaN
# ...            ...        ...        ...        ...        ...        ...
# 421565       3.882    4018.91      58.08      100.0     211.94     858.33
# 421566       3.882    4018.91      58.08      100.0     211.94     858.33
# 421567       3.882    4018.91      58.08      100.0     211.94     858.33
# 421568       3.882    4018.91      58.08      100.0     211.94     858.33
# 421569       3.882    4018.91      58.08      100.0     211.94     858.33
#
#                CPI  Unemployment Type    Size  week  year
# 0       211.096358         8.106    A  151315     5  2010
# 1       211.096358         8.106    A  151315     5  2010
# 2       211.096358         8.106    A  151315     5  2010
# 3       211.096358         8.106    A  151315     5  2010
# 4       211.096358         8.106    A  151315     5  2010
# ...            ...           ...  ...     ...   ...   ...
# 421565  192.308899         8.667    B  118221    43  2012
# 421566  192.308899         8.667    B  118221    43  2012
# 421567  192.308899         8.667    B  118221    43  2012
# 421568  192.308899         8.667    B  118221    43  2012
# 421569  192.308899         8.667    B  118221    43  2012
#
# [421570 rows x 18 columns]

# %%
df.Fuel_Price.unique()
# Out:
# array([2.572, 2.548, 2.514, 2.561, 2.625, 2.667, 2.72 , 2.732, 2.719,
#        2.77 , 2.808, 2.795, 2.78 , 2.835, 2.854, 2.826, 2.759, 2.705,
#        2.668, 2.637, 2.653, 2.669, 2.642, 2.623, 2.608, 2.64 , 2.627,
#        2.692, 2.664, 2.619, 2.577, 2.565, 2.582, 2.624, 2.603, 2.633,
#        2.725, 2.716, 2.689, 2.728, 2.771, 2.735, 2.708, 2.843, 2.869,
#        2.886, 2.943, 2.976, 2.983, 3.016, 3.01 , 2.989, 3.022, 3.045,
#        3.065, 3.288, 3.459, 3.488, 3.473, 3.524, 3.622, 3.743, 3.807,
#        3.81 , 3.906, 3.899, 3.907, 3.786, 3.699, 3.648, 3.637, 3.594,
#        4.044, 4.027, 4.004, 3.951, 3.889, 3.564, 3.475, 3.647, 3.654,
#        3.834, 3.867, 3.911, 3.948, 3.997, 4.   , 3.969, 2.954, 2.94 ,
#        2.909, 2.91 , 2.919, 2.938, 2.963, 2.957, 3.021, 3.042, 3.096,
#        3.006, 2.972, 2.942, 2.933, 2.932, 2.923, 2.913, 2.885, 2.84 ,
#        2.999, 3.138, 3.2  , 3.255, 3.301, 3.309, 3.351, 3.367, 3.391,
#        3.402, 3.4  , 3.416, 3.42 , 3.796, 3.895, 4.061, 4.117, 4.192,
#        4.211, 4.069, 4.025, 3.989, 3.964, 3.916, 3.915, 3.972, 4.02 ,
#        3.995, 3.942, 3.879, 3.93 , 3.937, 3.858, 3.775, 3.757, 3.719,
#        3.587, 3.826, 3.874, 3.983, 4.021, 4.054, 4.098, 4.143, 4.187,
#        4.17 , 4.163, 4.029, 3.979, 3.871, 3.819, 3.863, 4.026, 4.076,
#        4.203, 4.158, 4.153, 4.071, 2.747, 2.753, 2.834, 2.895, 2.981,
#        2.906, 2.857, 2.806, 2.796, 2.792, 2.878, 3.03 , 3.07 , 3.132,
#        3.139, 3.15 , 3.177, 3.215, 3.243, 3.24 , 3.281, 3.437, 3.634,
#        3.823, 3.919, 3.988, 4.078, 4.095, 4.101, 4.034, 3.973, 3.924,
#        3.873, 3.851, 3.88 , 3.758, 3.633, 3.604, 3.586, 3.536, 3.47 ,
#        3.439, 3.568, 3.751, 3.876, 3.921, 3.957, 4.023, 3.991, 3.947,
#        3.85 , 3.746, 3.629, 3.577, 3.84 , 3.884, 4.056, 4.018, 2.545,
#        2.539, 2.472, 2.52 , 2.769, 2.786, 2.767, 2.615, 2.601, 2.606,
#        2.596, 2.542, 2.602, 2.644, 2.604, 2.562, 2.533, 2.513, 2.578,
#        2.567, 2.595, 2.68 , 2.655, 2.694, 2.813, 2.852, 2.863, 2.995,
#        3.053, 3.448, 3.92 , 3.925, 3.69 , 3.502, 3.44 , 3.652, 3.608,
#        3.534, 3.481, 3.441, 3.328, 3.262, 3.234, 3.306, 3.254, 3.26 ,
#        3.181, 3.164, 3.147, 3.133, 3.098, 3.275, 3.313, 3.421, 3.462,
#        3.503, 3.934, 3.888, 3.835, 3.713, 3.358, 3.392, 3.404, 3.49 ,
#        3.576])

# %%
#check the type of the stores with highest avg sales and check the type of stores with lowesr avg sales
df[df['Store'].isin([20,4,14,13,2])]['Type'].value_counts()
# Out:
# A    51238
# Name: Type, dtype: int64

# %%
df[df['Store'].isin([33,5,44,3,38])]['Type'].value_counts()
# Out:
# B    18035
# C    14531
# A     6487
# Name: Type, dtype: int64

# %%
#sales and type of stores
a=df.groupby(['Type'])['Weekly_Sales'].mean()
a
# Out:
# Type
# A    20099.568043
# B    12237.075977
# C     9519.532538
# Name: Weekly_Sales, dtype: float64

# %%
sns.barplot(a.index,a.values)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Conclusion

# 1 higher the size more is the sales
# 2 each year almost same pattern so demand can be planned accordingly by considering last year's patterns
# 3 end year is having higher sales
# 4 store 20 having highest average. sales
# 5 store 5 is having loverst sales
# 5 dept 92 is having highest sales
# 6 dept 47 is having lowest sales
# 7 type a belongs to the larger stores
# 8 type c belongs to the smaller stores
